# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib as plt

# %%
df_c = pd.read_excel("online_retail_II.xlsx", sheet_name="Year 2010-2011")

# %%
df_c
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 541905  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 541909  581587      POST                              POSTAGE         1
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %%
df = df_c.copy()

# %%
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 541905  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 541909  581587      POST                              POSTAGE         1
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %%
df.describe().T
# Out:
#                 count          mean          std       min       25%  \
# Quantity     541910.0      9.552234   218.080957 -80995.00      1.00
# Price        541910.0      4.611138    96.759765 -11062.06      1.25
# Customer ID  406830.0  15287.684160  1713.603074  12346.00  13953.00
#
#                   50%       75%      max
# Quantity         3.00     10.00  80995.0
# Price            2.08      4.13  38970.0
# Customer ID  15152.00  16791.00  18287.0

# %%
df.isnull().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    135080
# Country             0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 541905  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 541909  581587      POST                              POSTAGE         1
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df["StockCode"].nunique()
# Out:
# 3684

# %%
df["StockCode"].value_counts()
# Out:
# 85123A    2077
# 22423     1905
# 85099B    1662
# 84879     1418
# 47566     1416
#           ...
# 84620        1
# 90038B       1
# 90038C       1
# 84614A       1
# 20957        1
# Name: StockCode, Length: 3684, dtype: int64

# %%
type(df["StockCode"].value_counts())
# Out:
# pandas.core.series.Series

# %%
a = df["StockCode"].value_counts().sort_values(ascending = False).head(5)

# %%
b = a.index.values.tolist()

# %%
df[df["StockCode"].isin(b)]
# Out:
#        Invoice StockCode                         Description  Quantity  \
# 0       536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 13      536367     84879       ASSORTED COLOUR BIRD ORNAMENT        32
# 49      536373    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 66      536375    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 177     536386    85099B             JUMBO BAG RED RETROSPOT       100
# ...        ...       ...                                 ...       ...
# 540217  581472    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 540434  581486    85099B             JUMBO BAG RED RETROSPOT        10
# 541263  581495     22423            REGENCY CAKESTAND 3 TIER        10
# 541639  581538    85123A  CREAM HANGING HEART T-LIGHT HOLDER         1
# 541875  581585     84879       ASSORTED COLOUR BIRD ORNAMENT        16
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %%
df = df[~df["Invoice"].astype(str).str.contains("C")]

# %%
df.describe().T
# Out:
#                 count          mean          std      min       25%       50%  \
# Quantity     397925.0     13.021793   180.419984      1.0      2.00      6.00
# Price        397925.0      3.116212    22.096773      0.0      1.25      1.95
# Customer ID  397925.0  15294.308601  1713.172738  12346.0  13969.00  15159.00
#
#                   75%       max
# Quantity        12.00  80995.00
# Price            3.75   8142.75
# Customer ID  16795.00  18287.00

# %%
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 541905  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 541909  581587      POST                              POSTAGE         1
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %%
df["Total_Price"] = df["Quantity"] * df["Price"]
# Out:
# C:\Users\90535\AppData\Local\Temp\ipykernel_18752\371581568.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Total_Price"] = df["Quantity"] * df["Price"]

# %%
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 541905  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 541909  581587      POST                              POSTAGE         1
#
#                InvoiceDate  Price  Customer ID         Country  Total_Price
# ...

# %%
import datetime as dt

# %%
today_date = dt.datetime(2011, 12, 11)

# %%
rfm = df.groupby("Customer ID").agg({"InvoiceDate":lambda x: (today_date-x.max()).days,"Invoice":lambda x: x.nunique(),"Total_Price":lambda x: x.sum()})

# %%
rfm.columns = ["recency","frequency","monetary"]

# %%
rfm
# Out:
#              recency  frequency  monetary
# Customer ID
# 12346.0          326          1  77183.60
# 12347.0            3          7   4310.00
# 12348.0           76          4   1797.24
# 12349.0           19          1   1757.55
# 12350.0          311          1    334.40
# ...              ...        ...       ...
# 18280.0          278          1    180.60
# 18281.0          181          1     80.82
# 18282.0            8          2    178.05
# 18283.0            4         16   2094.88
# 18287.0           43          3   1837.28
#
# [4339 rows x 3 columns]

# %%
rfm["recency_score"] = pd.qcut(rfm["recency"], 5, labels= [5,4,3,2,1])
rfm["frequency_score"] = pd.qcut(rfm["frequency"].rank(method = "first"), 5, labels= [1,2,3,4,5])
rfm["monetary_score"] = pd.qcut(rfm["monetary"], 5, labels= [1,2,3,4,5])

# %%
rfm
# Out:
#              recency  frequency  monetary recency_score frequency_score  \
# Customer ID
# 12346.0          326          1  77183.60             1               1
# 12347.0            3          7   4310.00             5               5
# 12348.0           76          4   1797.24             2               4
# 12349.0           19          1   1757.55             4               1
# 12350.0          311          1    334.40             1               1
# ...              ...        ...       ...           ...             ...
# 18280.0          278          1    180.60             1               2
# 18281.0          181          1     80.82             1               2
# 18282.0            8          2    178.05             5               3
# 18283.0            4         16   2094.88             5               5
# 18287.0           43          3   1837.28             3               4
#
#             monetary_score
# Customer ID
# 12346.0                  5
# ...

# %%
rfm["RF_SCORE"] = (rfm["recency_score"].astype(str)+ rfm["frequency_score"].astype(str))

# %%
rfm
# Out:
#              recency  frequency  monetary recency_score frequency_score  \
# Customer ID
# 12346.0          326          1  77183.60             1               1
# 12347.0            3          7   4310.00             5               5
# 12348.0           76          4   1797.24             2               4
# 12349.0           19          1   1757.55             4               1
# 12350.0          311          1    334.40             1               1
# ...              ...        ...       ...           ...             ...
# 18280.0          278          1    180.60             1               2
# 18281.0          181          1     80.82             1               2
# 18282.0            8          2    178.05             5               3
# 18283.0            4         16   2094.88             5               5
# 18287.0           43          3   1837.28             3               4
#
#             monetary_score RF_SCORE
# Customer ID
# 12346.0                  5       11
# ...

# %%
seg_map = {
    r'[1-2][1-2]': 'hibernating',
    r'[1-2][3-4]': 'at_Risk',
    r'[1-2]5': 'cant_loose',
    r'3[1-2]': 'about_to_sleep',
    r'33': 'need_attention',
    r'[3-4][4-5]': 'loyal_customers',
    r'41': 'promising',
    r'51': 'new_customers',
    r'[4-5][2-3]': 'potential_loyalists',
    r'5[4-5]': 'champions'}

# %%
rfm['segment'] = rfm['RF_SCORE'].replace(seg_map, regex=True)

# %%
rfm
# Out:
#              recency  frequency  monetary recency_score frequency_score  \
# Customer ID
# 12346.0          326          1  77183.60             1               1
# 12347.0            3          7   4310.00             5               5
# 12348.0           76          4   1797.24             2               4
# 12349.0           19          1   1757.55             4               1
# 12350.0          311          1    334.40             1               1
# ...              ...        ...       ...           ...             ...
# 18280.0          278          1    180.60             1               2
# 18281.0          181          1     80.82             1               2
# 18282.0            8          2    178.05             5               3
# 18283.0            4         16   2094.88             5               5
# 18287.0           43          3   1837.28             3               4
#
#             monetary_score RF_SCORE              segment
# Customer ID
# ...

# %%
rfm.groupby("segment").agg(["min","mean","max","count"])
# Out:
# C:\Users\90535\AppData\Local\Temp\ipykernel_18752\1338436814.py:1: FutureWarning: ['recency_score', 'frequency_score', 'monetary_score'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   rfm.groupby("segment").agg(["min","mean","max","count"])
#                     recency                        frequency                  \
#                         min        mean  max count       min       mean  max
# segment
# about_to_sleep           34   53.312500   72   352         1   1.161932    2
# at_Risk                  73  153.785835  374   593         2   2.878583    6
# cant_loose               73  132.968254  373    63         6   8.380952   34
# champions                 1    6.361769   13   633         3  12.417062  210
# hibernating              73  217.605042  374  1071         1   1.101774    2
# loyal_customers          15   33.608059   72   819         3   6.479853   63
# ...

# %%
loyal_customers_ID = rfm[rfm["segment"] == "loyal_customers"]

# %%
loyal_customers_ID = loyal_customers_ID.reset_index()

# %%
loyal_customers_ID["Customer ID"].to_csv("loyal_customers_ID.csv")
