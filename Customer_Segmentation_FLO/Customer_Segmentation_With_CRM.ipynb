# %% [markdown]
# READING DATASET

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib as plt

# %%
df_c = pd.read_csv("flo_data_20k.csv")

# %%
df = df_c.copy()

# %%
df["master_id"].nunique()
# Out:
# 19945

# %% [markdown]
# Understanding and Preparing Data

# %%
df
# Out:
#                                   master_id order_channel last_order_channel  \
# 0      cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1      f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2      69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3      1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4      d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
# ...                                     ...           ...                ...
# 19940  727e2b6e-ddd4-11e9-a848-000d3a38a36f   Android App            Offline
# 19941  25cd53d4-61bf-11ea-8dd8-000d3a38a36f       Desktop            Desktop
# 19942  8aea4c2a-d6fc-11e9-93bc-000d3a38a36f       Ios App            Ios App
# 19943  e50bb46c-ff30-11e9-a5e8-000d3a38a36f   Android App        Android App
# 19944  740998d2-b1f7-11e9-89fa-000d3a38a36f   Android App        Android App
#
# ...

# %%
for col_name in df.columns: 
    print(col_name)
# Out:
# master_id
# order_channel
# last_order_channel
# first_order_date
# last_order_date
# last_order_date_online
# last_order_date_offline
# order_num_total_ever_online
# order_num_total_ever_offline
# customer_value_total_ever_offline
# customer_value_total_ever_online
# interested_in_categories_12

# %%
df.describe().T
# Out:
#                                      count        mean         std    min  \
# order_num_total_ever_online        19945.0    3.110855    4.225647   1.00
# order_num_total_ever_offline       19945.0    1.913913    2.062880   1.00
# customer_value_total_ever_offline  19945.0  253.922597  301.532853  10.00
# customer_value_total_ever_online   19945.0  497.321690  832.601886  12.99
#
#                                       25%     50%     75%       max
# order_num_total_ever_online          1.00    2.00    4.00    200.00
# order_num_total_ever_offline         1.00    1.00    2.00    109.00
# customer_value_total_ever_offline   99.99  179.98  319.97  18119.14
# customer_value_total_ever_online   149.98  286.46  578.44  45220.13

# %%
df.isnull().sum()
# Out:
# master_id                            0
# order_channel                        0
# last_order_channel                   0
# first_order_date                     0
# last_order_date                      0
# last_order_date_online               0
# last_order_date_offline              0
# order_num_total_ever_online          0
# order_num_total_ever_offline         0
# customer_value_total_ever_offline    0
# customer_value_total_ever_online     0
# interested_in_categories_12          0
# dtype: int64

# %%
df.dtypes
# Out:
# master_id                             object
# order_channel                         object
# last_order_channel                    object
# first_order_date                      object
# last_order_date                       object
# last_order_date_online                object
# last_order_date_offline               object
# order_num_total_ever_online          float64
# order_num_total_ever_offline         float64
# customer_value_total_ever_offline    float64
# customer_value_total_ever_online     float64
# interested_in_categories_12           object
# dtype: object

# %%
df["total_order_num_ever"] = df["order_num_total_ever_online"] + df["order_num_total_ever_offline"]
df["total_customer_value_ever"] = (df["order_num_total_ever_offline"]* df["customer_value_total_ever_offline"]) + (df["order_num_total_ever_online"]* df["customer_value_total_ever_online"])

# %%
df
# Out:
#                                   master_id order_channel last_order_channel  \
# 0      cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1      f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2      69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3      1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4      d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
# ...                                     ...           ...                ...
# 19940  727e2b6e-ddd4-11e9-a848-000d3a38a36f   Android App            Offline
# 19941  25cd53d4-61bf-11ea-8dd8-000d3a38a36f       Desktop            Desktop
# 19942  8aea4c2a-d6fc-11e9-93bc-000d3a38a36f       Ios App            Ios App
# 19943  e50bb46c-ff30-11e9-a5e8-000d3a38a36f   Android App        Android App
# 19944  740998d2-b1f7-11e9-89fa-000d3a38a36f   Android App        Android App
#
# ...

# %%
df.dtypes
# Out:
# master_id                             object
# order_channel                         object
# last_order_channel                    object
# first_order_date                      object
# last_order_date                       object
# last_order_date_online                object
# last_order_date_offline               object
# order_num_total_ever_online          float64
# order_num_total_ever_offline         float64
# customer_value_total_ever_offline    float64
# customer_value_total_ever_online     float64
# interested_in_categories_12           object
# total_order_num_ever                 float64
# total_customer_value_ever            float64
# dtype: object

# %%
import datetime as dt

# %%
df['first_order_date'] = pd.to_datetime(df['first_order_date'])
df['last_order_date'] = pd.to_datetime(df['last_order_date'])
df['last_order_date_online'] = pd.to_datetime(df['last_order_date_online'])
df['last_order_date_offline'] = pd.to_datetime(df['last_order_date_offline'])

# %%
df.dtypes
# Out:
# master_id                                    object
# order_channel                                object
# last_order_channel                           object
# first_order_date                     datetime64[ns]
# last_order_date                      datetime64[ns]
# last_order_date_online               datetime64[ns]
# last_order_date_offline              datetime64[ns]
# order_num_total_ever_online                 float64
# order_num_total_ever_offline                float64
# customer_value_total_ever_offline           float64
# customer_value_total_ever_online            float64
# interested_in_categories_12                  object
# total_order_num_ever                        float64
# total_customer_value_ever                   float64
# dtype: object

# %%
def q1(x):
    return x.quantile(0.25)
def q2(x):
    return x.quantile(0.5)

def q3(x):
    return x.quantile(0.75)

def q4(x):
    return x.quantile(0.99)



df.groupby("order_channel").agg({"master_id" : "count", "total_order_num_ever": ["min","max","mean","sum",q1,q2,q3,q4] , "total_customer_value_ever" : ["min","max","mean","sum",q1,q2,q3,q4]})
# Out:
#               master_id total_order_num_ever                                 \
#                   count                  min    max      mean      sum   q1
# order_channel
# Android App        9495                  2.0  202.0  5.504897  52269.0  3.0
# Desktop            2735                  2.0   70.0  3.992687  10920.0  2.0
# Ios App            2833                  2.0   83.0  5.418637  15351.0  3.0
# Mobile             4882                  2.0   77.0  4.440598  21679.0  2.0
#
#                                total_customer_value_ever              \
#                 q2   q3     q4                       min         max
# order_channel
# Android App    4.0  6.0  24.00                     55.98  9045395.94
# Desktop        3.0  5.0  16.00                     44.98  1164967.46
# Ios App        4.0  6.0  25.68                     69.98  2646265.30
# Mobile         3.0  5.0  20.00                     44.98   451814.05
#
# ...

# %%
df["master_id"].nunique()
# Out:
# 19945

# %%
df.shape
# Out:
# (19945, 14)

# %%
df.sort_values( by= "total_customer_value_ever", ascending = False).head(10)
# Out:
#                                   master_id order_channel last_order_channel  \
# 11150  5d1c466a-9cfd-11e9-9897-000d3a38a36f   Android App            Desktop
# 7613   73fd19aa-9e37-11e9-9897-000d3a38a36f       Ios App            Offline
# 4315   d5ef8058-a5c6-11e9-a2fc-000d3a38a36f   Android App        Android App
# 7223   cba59206-9dd1-11e9-9897-000d3a38a36f   Android App        Android App
# 7330   a4d534a2-5b1b-11eb-8dbd-000d3a38a36f       Desktop            Desktop
# 8068   d696c654-2633-11ea-8e1c-000d3a38a36f       Ios App            Ios App
# 8783   a57f4302-b1a8-11e9-89fa-000d3a38a36f   Android App            Offline
# 2619   fdbe8304-a7ab-11e9-a2fc-000d3a38a36f   Android App            Offline
# 163    fef57ffa-aae6-11e9-a2fc-000d3a38a36f        Mobile            Desktop
# 6337   f7e2335e-a7c4-11e9-a2fc-000d3a38a36f       Ios App             Mobile
#
#       first_order_date last_order_date last_order_date_online  \
# ...

# %%
df.sort_values( by= "total_order_num_ever", ascending = False).head(10)
# Out:
#                                   master_id order_channel last_order_channel  \
# 11150  5d1c466a-9cfd-11e9-9897-000d3a38a36f   Android App            Desktop
# 7223   cba59206-9dd1-11e9-9897-000d3a38a36f   Android App        Android App
# 8783   a57f4302-b1a8-11e9-89fa-000d3a38a36f   Android App            Offline
# 2619   fdbe8304-a7ab-11e9-a2fc-000d3a38a36f   Android App            Offline
# 6322   329968c6-a0e2-11e9-a2fc-000d3a38a36f       Ios App            Ios App
# 7613   73fd19aa-9e37-11e9-9897-000d3a38a36f       Ios App            Offline
# 9347   44d032ee-a0d4-11e9-a2fc-000d3a38a36f        Mobile             Mobile
# 10954  b27e241a-a901-11e9-a2fc-000d3a38a36f        Mobile             Mobile
# 8068   d696c654-2633-11ea-8e1c-000d3a38a36f       Ios App            Ios App
# 7330   a4d534a2-5b1b-11eb-8dbd-000d3a38a36f       Desktop            Desktop
#
#       first_order_date last_order_date last_order_date_online  \
# ...

# %%
print("##############################")
print(df.groupby("order_channel").agg({"master_id" : "count", "total_order_num_ever": ["min","max","mean","sum",q1,q2,q3,q4] , "total_customer_value_ever" : ["min","max","mean","sum",q1,q2,q3,q4]}))
# Out:
# ##############################
#               master_id total_order_num_ever                                 \
#                   count                  min    max      mean      sum   q1
# order_channel
# Android App        9495                  2.0  202.0  5.504897  52269.0  3.0
# Desktop            2735                  2.0   70.0  3.992687  10920.0  2.0
# Ios App            2833                  2.0   83.0  5.418637  15351.0  3.0
# Mobile             4882                  2.0   77.0  4.440598  21679.0  2.0
#
#                                total_customer_value_ever              \
#                 q2   q3     q4                       min         max
# order_channel
# Android App    4.0  6.0  24.00                     55.98  9045395.94
# Desktop        3.0  5.0  16.00                     44.98  1164967.46
# Ios App        4.0  6.0  25.68                     69.98  2646265.30
# Mobile         3.0  5.0  20.00                     44.98   451814.05
#
# ...

# %%
def Data_preparation_process (dataframe ,head =10) :
    print("Shape : ",dataframe.shape)
    print("##############################")
    print("Col_names")
    for col_name in dataframe.columns: 
        print(col_name)
    print("##############################")
    print("First_ten_index_: \n", dataframe.head(head))
    print("##############################")
    print("Null_values : \n", dataframe.isnull().sum())
    print("##############################")
    print("Types of columns : \n",df.dtypes)
    print("##############################")
    print("Statistics : \n",dataframe.describe().T)
    print("##############################")
    print("Object type to date type start")
    dataframe['first_order_date'] = pd.to_datetime(dataframe['first_order_date'])
    dataframe['last_order_date'] = pd.to_datetime(dataframe['last_order_date'])
    dataframe['last_order_date_online'] = pd.to_datetime(dataframe['last_order_date_online'])
    dataframe['last_order_date_offline'] = pd.to_datetime(dataframe['last_order_date_offline'])
    print("Object type to date type finish")
    print("##############################")
    dataframe["total_order_num_ever"] = dataframe["order_num_total_ever_online"] + dataframe["order_num_total_ever_offline"]
    dataframe["total_customer_value_ever"] = (dataframe["order_num_total_ever_offline"]* dataframe["customer_value_total_ever_offline"]) + (dataframe["order_num_total_ever_online"]* dataframe["customer_value_total_ever_online"])
    print("total_order_num_ever and total_customer_value_ever added")
    print("##############################")
    print("statistics for order_channel :")
    def q1(x):
        return x.quantile(0.25)
    def q2(x):
        return x.quantile(0.5)

    def q3(x):
        return x.quantile(0.75)

    def q4(x):
        return x.quantile(0.99)



    print(dataframe.groupby("order_channel").agg({"master_id" : "count", "total_order_num_ever": ["min","max","mean","sum",q1,q2,q3,q4] , "total_customer_value_ever" : ["min","max","mean","sum",q1,q2,q3,q4]}))
    print("##############################")
    print("Top 10 customers who spend the most")
    print(dataframe.sort_values( by= "total_customer_value_ever", ascending = False).head(head))
    print("##############################")
    print("Top 10 customers who spend the most frequently")
    print(dataframe.sort_values( by= "total_order_num_ever", ascending = False).head(head))

# %% [markdown]
# RFM SCORES

# %%
today_date = dt.datetime(2021,6,2)

# %%
df["recency"] = df.apply(lambda x: (today_date-x["last_order_date"]).days, axis=1)
df["frequency"] = df["total_order_num_ever"]
df["monetary"] = df["total_customer_value_ever"]

# %%
df
# Out:
#                                   master_id order_channel last_order_channel  \
# 0      cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1      f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2      69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3      1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4      d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
# ...                                     ...           ...                ...
# 19940  727e2b6e-ddd4-11e9-a848-000d3a38a36f   Android App            Offline
# 19941  25cd53d4-61bf-11ea-8dd8-000d3a38a36f       Desktop            Desktop
# 19942  8aea4c2a-d6fc-11e9-93bc-000d3a38a36f       Ios App            Ios App
# 19943  e50bb46c-ff30-11e9-a5e8-000d3a38a36f   Android App        Android App
# 19944  740998d2-b1f7-11e9-89fa-000d3a38a36f   Android App        Android App
#
# ...

# %%
rfm = df.filter(["master_id",'recency','frequency','monetary'], axis=1)

# %%
rfm
# Out:
#                                   master_id  recency  frequency  monetary
# 0      cc294636-19f0-11eb-8d74-000d3a38a36f       96        5.0   3337.51
# 1      f431bd5a-ab7b-11e9-a2fc-000d3a38a36f      106       21.0  35537.96
# 2      69b69676-1a40-11ea-941b-000d3a38a36f      187        5.0   1565.99
# 3      1854e56c-491f-11eb-806e-000d3a38a36f      136        2.0    121.97
# 4      d6ea1074-f1f5-11e9-9346-000d3a38a36f       87        2.0    209.98
# ...                                     ...      ...        ...       ...
# 19940  727e2b6e-ddd4-11e9-a848-000d3a38a36f      332        3.0    691.94
# 19941  25cd53d4-61bf-11ea-8dd8-000d3a38a36f      162        2.0    390.47
# 19942  8aea4c2a-d6fc-11e9-93bc-000d3a38a36f        9        3.0   1125.90
# 19943  e50bb46c-ff30-11e9-a5e8-000d3a38a36f      109        6.0   3856.93
# 19944  740998d2-b1f7-11e9-89fa-000d3a38a36f      361        2.0    261.97
#
# [19945 rows x 4 columns]

# %% [markdown]
# CALCULATING RFM SCORES

# %%
rfm["recency_score"] = pd.qcut(rfm["recency"], 5, labels= [5,4,3,2,1])
rfm["frequency_score"] = pd.qcut(rfm["frequency"].rank(method = "first"), 5, labels= [1,2,3,4,5])
rfm["monetary_score"] = pd.qcut(rfm["monetary"], 5, labels= [1,2,3,4,5])

# %%
rfm
# Out:
#                                   master_id  recency  frequency  monetary  \
# 0      cc294636-19f0-11eb-8d74-000d3a38a36f       96        5.0   3337.51
# 1      f431bd5a-ab7b-11e9-a2fc-000d3a38a36f      106       21.0  35537.96
# 2      69b69676-1a40-11ea-941b-000d3a38a36f      187        5.0   1565.99
# 3      1854e56c-491f-11eb-806e-000d3a38a36f      136        2.0    121.97
# 4      d6ea1074-f1f5-11e9-9346-000d3a38a36f       87        2.0    209.98
# ...                                     ...      ...        ...       ...
# 19940  727e2b6e-ddd4-11e9-a848-000d3a38a36f      332        3.0    691.94
# 19941  25cd53d4-61bf-11ea-8dd8-000d3a38a36f      162        2.0    390.47
# 19942  8aea4c2a-d6fc-11e9-93bc-000d3a38a36f        9        3.0   1125.90
# 19943  e50bb46c-ff30-11e9-a5e8-000d3a38a36f      109        6.0   3856.93
# 19944  740998d2-b1f7-11e9-89fa-000d3a38a36f      361        2.0    261.97
#
#       recency_score frequency_score monetary_score
# ...

# %%
rfm["RF_SCORE"] = (rfm["recency_score"].astype(str)+ rfm["frequency_score"].astype(str))

# %%
rfm
# Out:
#                                   master_id  recency  frequency  monetary  \
# 0      cc294636-19f0-11eb-8d74-000d3a38a36f       96        5.0   3337.51
# 1      f431bd5a-ab7b-11e9-a2fc-000d3a38a36f      106       21.0  35537.96
# 2      69b69676-1a40-11ea-941b-000d3a38a36f      187        5.0   1565.99
# 3      1854e56c-491f-11eb-806e-000d3a38a36f      136        2.0    121.97
# 4      d6ea1074-f1f5-11e9-9346-000d3a38a36f       87        2.0    209.98
# ...                                     ...      ...        ...       ...
# 19940  727e2b6e-ddd4-11e9-a848-000d3a38a36f      332        3.0    691.94
# 19941  25cd53d4-61bf-11ea-8dd8-000d3a38a36f      162        2.0    390.47
# 19942  8aea4c2a-d6fc-11e9-93bc-000d3a38a36f        9        3.0   1125.90
# 19943  e50bb46c-ff30-11e9-a5e8-000d3a38a36f      109        6.0   3856.93
# 19944  740998d2-b1f7-11e9-89fa-000d3a38a36f      361        2.0    261.97
#
#       recency_score frequency_score monetary_score RF_SCORE
# ...

# %%
seg_map = {
    r'[1-2][1-2]': 'hibernating',
    r'[1-2][3-4]': 'at_Risk',
    r'[1-2]5': 'cant_loose',
    r'3[1-2]': 'about_to_sleep',
    r'33': 'need_attention',
    r'[3-4][4-5]': 'loyal_customers',
    r'41': 'promising',
    r'51': 'new_customers',
    r'[4-5][2-3]': 'potential_loyalists',
    r'5[4-5]': 'champions'}

# %%
rfm['segment'] = rfm['RF_SCORE'].replace(seg_map, regex=True)

# %%
rfm
# Out:
#                                   master_id  recency  frequency  monetary  \
# 0      cc294636-19f0-11eb-8d74-000d3a38a36f       96        5.0   3337.51
# 1      f431bd5a-ab7b-11e9-a2fc-000d3a38a36f      106       21.0  35537.96
# 2      69b69676-1a40-11ea-941b-000d3a38a36f      187        5.0   1565.99
# 3      1854e56c-491f-11eb-806e-000d3a38a36f      136        2.0    121.97
# 4      d6ea1074-f1f5-11e9-9346-000d3a38a36f       87        2.0    209.98
# ...                                     ...      ...        ...       ...
# 19940  727e2b6e-ddd4-11e9-a848-000d3a38a36f      332        3.0    691.94
# 19941  25cd53d4-61bf-11ea-8dd8-000d3a38a36f      162        2.0    390.47
# 19942  8aea4c2a-d6fc-11e9-93bc-000d3a38a36f        9        3.0   1125.90
# 19943  e50bb46c-ff30-11e9-a5e8-000d3a38a36f      109        6.0   3856.93
# 19944  740998d2-b1f7-11e9-89fa-000d3a38a36f      361        2.0    261.97
#
#       recency_score frequency_score monetary_score RF_SCORE  \
# ...

# %% [markdown]
# STATISTICS OF SEGMENTS

# %%
rfm.groupby("segment").agg(["mean","max","min"]).drop("RF_SCORE",axis=1)
# Out:
# C:\Users\90535\AppData\Local\Temp\ipykernel_22620\1734638186.py:1: FutureWarning: ['master_id', 'recency_score', 'frequency_score', 'monetary_score'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   rfm.groupby("segment").agg(["mean","max","min"]).drop("RF_SCORE",axis=1)
#                         recency            frequency              \
#                            mean  max  min       mean    max  min
# segment
# about_to_sleep       114.785144  146   85   2.401473    3.0  2.0
# at_Risk              242.606835  368  147   4.472373    7.0  3.0
# cant_loose           236.444167  368  147  10.698333  111.0  7.0
# champions             18.106625   34    3   8.934265  202.0  4.0
# hibernating          248.949501  368  147   2.394007    3.0  2.0
# loyal_customers       83.594763  146   35   8.374591   83.0  4.0
# need_attention       114.828676  146   85   3.727825    4.0  3.0
# ...

# %% [markdown]
# LISTING THE NECESSARY CUSTOMERS

# %%
new_df = pd.merge(rfm, df, on='master_id', how='inner')

# %%
new_df
# Out:
#                                   master_id  recency_x  frequency_x  \
# 0      cc294636-19f0-11eb-8d74-000d3a38a36f         96          5.0
# 1      f431bd5a-ab7b-11e9-a2fc-000d3a38a36f        106         21.0
# 2      69b69676-1a40-11ea-941b-000d3a38a36f        187          5.0
# 3      1854e56c-491f-11eb-806e-000d3a38a36f        136          2.0
# 4      d6ea1074-f1f5-11e9-9346-000d3a38a36f         87          2.0
# ...                                     ...        ...          ...
# 19940  727e2b6e-ddd4-11e9-a848-000d3a38a36f        332          3.0
# 19941  25cd53d4-61bf-11ea-8dd8-000d3a38a36f        162          2.0
# 19942  8aea4c2a-d6fc-11e9-93bc-000d3a38a36f          9          3.0
# 19943  e50bb46c-ff30-11e9-a5e8-000d3a38a36f        109          6.0
# 19944  740998d2-b1f7-11e9-89fa-000d3a38a36f        361          2.0
#
#        monetary_x recency_score frequency_score monetary_score RF_SCORE  \
# 0         3337.51             3               4              4       34
# ...

# %%
customer_list_1 = new_df[(new_df["segment"] == "champions") | (new_df["segment"] == "loyal_customers")]

# %%
customer_list_1 = customer_list_1[customer_list_1["interested_in_categories_12"].str.contains("KADIN")]

# %%
customer_list_1.to_csv("customer_list_1.csv")

# %% [markdown]
# B PART

# %%
new_df
# Out:
#                                   master_id  recency_x  frequency_x  \
# 0      cc294636-19f0-11eb-8d74-000d3a38a36f         96          5.0
# 1      f431bd5a-ab7b-11e9-a2fc-000d3a38a36f        106         21.0
# 2      69b69676-1a40-11ea-941b-000d3a38a36f        187          5.0
# 3      1854e56c-491f-11eb-806e-000d3a38a36f        136          2.0
# 4      d6ea1074-f1f5-11e9-9346-000d3a38a36f         87          2.0
# ...                                     ...        ...          ...
# 19940  727e2b6e-ddd4-11e9-a848-000d3a38a36f        332          3.0
# 19941  25cd53d4-61bf-11ea-8dd8-000d3a38a36f        162          2.0
# 19942  8aea4c2a-d6fc-11e9-93bc-000d3a38a36f          9          3.0
# 19943  e50bb46c-ff30-11e9-a5e8-000d3a38a36f        109          6.0
# 19944  740998d2-b1f7-11e9-89fa-000d3a38a36f        361          2.0
#
#        monetary_x recency_score frequency_score monetary_score RF_SCORE  \
# 0         3337.51             3               4              4       34
# ...

# %%
customer_list_2 = new_df[(new_df["segment"] == "about_to_sleep") | (new_df["segment"] == "cant_loose")| (new_df["segment"] == "new_customers")]

# %%
customer_list_2 = customer_list_2[(customer_list_2["interested_in_categories_12"].str.contains("ERKEK"))|(customer_list_2["interested_in_categories_12"].str.contains("COCUK"))]

# %%
customer_list_2.to_csv("customer_list_2.csv")
